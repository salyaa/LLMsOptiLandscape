# %% [markdown]
# ## Optimizer Experiments
#
# ### Configuration

# %%
import os
# Set the environment variable for CUDA devices
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# !export CUDA_VISIBLE_DEVICES=3

import warnings
import torch
from optimization.experiments import run_experiment, plot_experiment, calc_sharpness
from utils.config_loader import load_config
from utils.plots import plot_loss_curves
from utils.misc import set_seed, create_loaders

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*?.*")
warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch\.backends\.cuda\.sdp_kernel.*")

# Load config
config = load_config("config/base.yaml")

# Device setup
config.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set random seed for reproducibility
set_seed(42)
# set_seed(30)

# Set a default number of epochs for experiments
EPOCHS = 60

# Create the results and plots directories if they do not exist
os.makedirs("exp_results", exist_ok=True)
os.makedirs("exp_plots", exist_ok=True)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\.'
# <>:16: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_59038/1202273696.py:16: SyntaxWarning: invalid escape sequence '\.'
#   warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch\.backends\.cuda\.sdp_kernel.*")

# %% [markdown]
# ### Experiments

# %%
# Clear CUDA cache
torch.cuda.empty_cache()

# Define experiments
experiments = [
    {'optimizer_class': torch.optim.AdamW, 'lr': 0.0001, 'batch_size': 1, 'shuffle_mode': 'random', 'weight_decay': 0.0005},
    {'optimizer_class': torch.optim.AdamW, 'lr': 0.0001, 'batch_size': 32, 'shuffle_mode': 'random', 'weight_decay': 0.0005},
]

# Initialize results and models list
results_list = []
models_list = []
models_names = []
    
# Run experiments
for exp in experiments:
    print(f"\nRunning experiment with {exp['optimizer_class'].__name__}, lr={exp['lr']}, bs={exp['batch_size']}, shuffle={exp['shuffle_mode']}, wd: {exp['weight_decay']}")
    
    results, model = run_experiment(
            config=config,
            optimizer_class=exp['optimizer_class'],
            lr=exp['lr'],
            weight_decay=exp['weight_decay'],
            batch_size=exp['batch_size'],
            epochs=EPOCHS,
            shuffle_mode=exp['shuffle_mode'],
        )
    
    results_list.append(results)
    models_list.append(model)

    # Generate a consistent filename
    fname = f"{exp['optimizer_class'].__name__}_{exp['lr']}_{exp['batch_size']}_{exp['shuffle_mode']}_{exp['weight_decay']}"

    # Save model state dict
    torch.save(model.state_dict(), f"exp_results/model_params_{fname}.pt")
    models_names.append(f"model_params_{fname}.pt")

    # Save results dict
    torch.save(results, f"exp_results/results_{fname}.pt")

# Plot loss curves with named output
if len(experiments) == 1:
    exp = experiments[0]
    fname = f"{exp['optimizer_class'].__name__}_{exp['lr']}_{exp['batch_size']}_{exp['shuffle_mode']}_{exp['weight_decay']}"
else:
    fname = "optimizer_experiments"

plot_loss_curves(results_list, save_path="exp_plots", fname=fname)

# Print exepriment summary
print("\nExperiments Summary:")
for res in results_list:
    print(f"\nOptimizer: {res['optimizer']}")
    print(f"LR: {res['lr']}, Shuffle: {res['shuffle_mode']}, Batch Size: {res['batch_size']}, Weight Decay: {res['weight_decay']}")
    print(f"Final Train Loss: {res['train_loss']:.4f}, Val Loss: {res['val_loss']:.4f}")
# Out:
# Running experiment with AdamW, lr=0.0001, bs=1, shuffle=random, wd: 0.0005
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Epoch 1/60 - Train Loss: 3.6667, Val Loss: 3.1649, Val Perplexity: 23.69
# Epoch 2/60 - Train Loss: 2.7752, Val Loss: 3.2375, Val Perplexity: 25.47
# Epoch 3/60 - Train Loss: 2.3207, Val Loss: 3.3902, Val Perplexity: 29.67
# Epoch 4/60 - Train Loss: 1.9234, Val Loss: 3.6270, Val Perplexity: 37.60
# Epoch 5/60 - Train Loss: 1.5580, Val Loss: 3.8801, Val Perplexity: 48.43
# Epoch 6/60 - Train Loss: 1.2334, Val Loss: 4.1273, Val Perplexity: 62.01
# Epoch 7/60 - Train Loss: 0.9631, Val Loss: 4.3673, Val Perplexity: 78.83
# Epoch 8/60 - Train Loss: 0.7595, Val Loss: 4.5962, Val Perplexity: 99.11
# Epoch 9/60 - Train Loss: 0.5976, Val Loss: 4.7580, Val Perplexity: 116.51
# Epoch 10/60 - Train Loss: 0.4747, Val Loss: 4.8849, Val Perplexity: 132.27
# Epoch 11/60 - Train Loss: 0.3932, Val Loss: 5.0432, Val Perplexity: 154.96
# Epoch 12/60 - Train Loss: 0.3361, Val Loss: 5.1696, Val Perplexity: 175.85
# Epoch 13/60 - Train Loss: 0.2890, Val Loss: 5.2567, Val Perplexity: 191.85
# Epoch 14/60 - Train Loss: 0.2559, Val Loss: 5.3487, Val Perplexity: 210.34
# Epoch 15/60 - Train Loss: 0.2307, Val Loss: 5.3764, Val Perplexity: 216.24
# Epoch 16/60 - Train Loss: 0.2092, Val Loss: 5.5015, Val Perplexity: 245.07
# Epoch 17/60 - Train Loss: 0.1924, Val Loss: 5.5671, Val Perplexity: 261.68
# Epoch 18/60 - Train Loss: 0.1714, Val Loss: 5.5797, Val Perplexity: 265.00
# Epoch 19/60 - Train Loss: 0.1607, Val Loss: 5.7090, Val Perplexity: 301.56
# Epoch 20/60 - Train Loss: 0.1553, Val Loss: 5.7188, Val Perplexity: 304.53
# Epoch 21/60 - Train Loss: 0.1465, Val Loss: 5.7636, Val Perplexity: 318.49
# Epoch 22/60 - Train Loss: 0.1375, Val Loss: 5.7593, Val Perplexity: 317.14
# Epoch 23/60 - Train Loss: 0.1279, Val Loss: 5.8689, Val Perplexity: 353.86
# Epoch 24/60 - Train Loss: 0.1233, Val Loss: 5.8649, Val Perplexity: 352.44
# Epoch 25/60 - Train Loss: 0.1158, Val Loss: 5.9816, Val Perplexity: 396.07
# Epoch 26/60 - Train Loss: 0.1124, Val Loss: 5.9285, Val Perplexity: 375.60
# Epoch 27/60 - Train Loss: 0.1134, Val Loss: 6.1070, Val Perplexity: 448.97
# Epoch 28/60 - Train Loss: 0.1033, Val Loss: 6.1398, Val Perplexity: 463.95
# Epoch 29/60 - Train Loss: 0.1007, Val Loss: 6.1572, Val Perplexity: 472.08
# Epoch 30/60 - Train Loss: 0.0957, Val Loss: 6.1902, Val Perplexity: 487.93
# Epoch 31/60 - Train Loss: 0.0961, Val Loss: 6.2413, Val Perplexity: 513.55
# Epoch 32/60 - Train Loss: 0.0915, Val Loss: 6.2156, Val Perplexity: 500.49
# Epoch 33/60 - Train Loss: 0.0900, Val Loss: 6.2707, Val Perplexity: 528.84
# Epoch 34/60 - Train Loss: 0.0889, Val Loss: 6.2378, Val Perplexity: 511.73
# Epoch 35/60 - Train Loss: 0.0860, Val Loss: 6.2735, Val Perplexity: 530.33
# Epoch 36/60 - Train Loss: 0.0832, Val Loss: 6.3358, Val Perplexity: 564.41
# Epoch 37/60 - Train Loss: 0.0820, Val Loss: 6.3842, Val Perplexity: 592.43
# Epoch 38/60 - Train Loss: 0.0789, Val Loss: 6.3903, Val Perplexity: 596.01
# Epoch 39/60 - Train Loss: 0.0792, Val Loss: 6.4053, Val Perplexity: 605.04
# Epoch 40/60 - Train Loss: 0.0812, Val Loss: 6.4915, Val Perplexity: 659.50
# Epoch 41/60 - Train Loss: 0.0733, Val Loss: 6.4215, Val Perplexity: 614.93
# Epoch 42/60 - Train Loss: 0.0725, Val Loss: 6.4142, Val Perplexity: 610.48
# Epoch 43/60 - Train Loss: 0.0748, Val Loss: 6.4678, Val Perplexity: 644.05
# Epoch 44/60 - Train Loss: 0.0736, Val Loss: 6.5380, Val Perplexity: 690.93
# Epoch 45/60 - Train Loss: 0.0715, Val Loss: 6.6181, Val Perplexity: 748.53
# Epoch 46/60 - Train Loss: 0.0680, Val Loss: 6.5369, Val Perplexity: 690.12
# Epoch 47/60 - Train Loss: 0.0687, Val Loss: 6.6234, Val Perplexity: 752.50
# Epoch 48/60 - Train Loss: 0.0672, Val Loss: 6.6728, Val Perplexity: 790.61
# Epoch 49/60 - Train Loss: 0.0683, Val Loss: 6.5394, Val Perplexity: 691.89
# Epoch 50/60 - Train Loss: 0.0657, Val Loss: 6.5688, Val Perplexity: 712.50
# Epoch 51/60 - Train Loss: 0.0631, Val Loss: 6.7273, Val Perplexity: 834.89
# Epoch 52/60 - Train Loss: 0.0660, Val Loss: 6.6628, Val Perplexity: 782.75
# Epoch 53/60 - Train Loss: 0.0628, Val Loss: 6.7140, Val Perplexity: 823.89
# Epoch 54/60 - Train Loss: 0.0626, Val Loss: 6.6971, Val Perplexity: 810.04
# Epoch 55/60 - Train Loss: 0.0620, Val Loss: 6.7658, Val Perplexity: 867.64
# Epoch 56/60 - Train Loss: 0.0614, Val Loss: 6.7959, Val Perplexity: 894.17
# Epoch 57/60 - Train Loss: 0.0602, Val Loss: 6.7489, Val Perplexity: 853.14
# Epoch 58/60 - Train Loss: 0.0592, Val Loss: 6.7655, Val Perplexity: 867.39
# Epoch 59/60 - Train Loss: 0.0598, Val Loss: 6.7389, Val Perplexity: 844.67
# Epoch 60/60 - Train Loss: 0.0579, Val Loss: 6.7704, Val Perplexity: 871.70
#
# Running experiment with AdamW, lr=0.0001, bs=32, shuffle=random, wd: 0.0005
# Epoch 1/60 - Train Loss: 8.5308, Val Loss: 8.6964, Val Perplexity: 5981.51
# Epoch 2/60 - Train Loss: 8.1888, Val Loss: 7.4262, Val Perplexity: 1679.49
# Epoch 3/60 - Train Loss: 6.9303, Val Loss: 5.9812, Val Perplexity: 395.93
# Epoch 4/60 - Train Loss: 5.8527, Val Loss: 5.1487, Val Perplexity: 172.20
# Epoch 5/60 - Train Loss: 5.1647, Val Loss: 4.5585, Val Perplexity: 95.44
# Epoch 6/60 - Train Loss: 4.6797, Val Loss: 4.2088, Val Perplexity: 67.28
# Epoch 7/60 - Train Loss: 4.3430, Val Loss: 3.9936, Val Perplexity: 54.25
# Epoch 8/60 - Train Loss: 4.1090, Val Loss: 3.8802, Val Perplexity: 48.43
# Epoch 9/60 - Train Loss: 3.9233, Val Loss: 3.8022, Val Perplexity: 44.80
# Epoch 10/60 - Train Loss: 3.7889, Val Loss: 3.7622, Val Perplexity: 43.04
# Epoch 11/60 - Train Loss: 3.6762, Val Loss: 3.7070, Val Perplexity: 40.73
# Epoch 12/60 - Train Loss: 3.5768, Val Loss: 3.6805, Val Perplexity: 39.67
# Epoch 13/60 - Train Loss: 3.4912, Val Loss: 3.6925, Val Perplexity: 40.14
# Epoch 14/60 - Train Loss: 3.4114, Val Loss: 3.6720, Val Perplexity: 39.33
# Epoch 15/60 - Train Loss: 3.3384, Val Loss: 3.6548, Val Perplexity: 38.66
# Epoch 16/60 - Train Loss: 3.2660, Val Loss: 3.6657, Val Perplexity: 39.08
# Epoch 17/60 - Train Loss: 3.1999, Val Loss: 3.6648, Val Perplexity: 39.05
# Epoch 18/60 - Train Loss: 3.1417, Val Loss: 3.6537, Val Perplexity: 38.62
# Epoch 19/60 - Train Loss: 3.0805, Val Loss: 3.6651, Val Perplexity: 39.06
# Epoch 20/60 - Train Loss: 3.0261, Val Loss: 3.6702, Val Perplexity: 39.26
# Epoch 21/60 - Train Loss: 2.9751, Val Loss: 3.6762, Val Perplexity: 39.50
# Epoch 22/60 - Train Loss: 2.9175, Val Loss: 3.6680, Val Perplexity: 39.18
# Epoch 23/60 - Train Loss: 2.8732, Val Loss: 3.6889, Val Perplexity: 40.00
# Epoch 24/60 - Train Loss: 2.8196, Val Loss: 3.6879, Val Perplexity: 39.96
# Epoch 25/60 - Train Loss: 2.7670, Val Loss: 3.6983, Val Perplexity: 40.38
# Epoch 26/60 - Train Loss: 2.7224, Val Loss: 3.7117, Val Perplexity: 40.92
# Epoch 27/60 - Train Loss: 2.6714, Val Loss: 3.7181, Val Perplexity: 41.18
# Epoch 28/60 - Train Loss: 2.6231, Val Loss: 3.7320, Val Perplexity: 41.76
# Epoch 29/60 - Train Loss: 2.5770, Val Loss: 3.7338, Val Perplexity: 41.84
# Epoch 30/60 - Train Loss: 2.5374, Val Loss: 3.7555, Val Perplexity: 42.75
# Epoch 31/60 - Train Loss: 2.4868, Val Loss: 3.7665, Val Perplexity: 43.23
# Epoch 32/60 - Train Loss: 2.4402, Val Loss: 3.7725, Val Perplexity: 43.49
# Epoch 33/60 - Train Loss: 2.3965, Val Loss: 3.7930, Val Perplexity: 44.39
# Epoch 34/60 - Train Loss: 2.3511, Val Loss: 3.8002, Val Perplexity: 44.71
# Epoch 35/60 - Train Loss: 2.3112, Val Loss: 3.8228, Val Perplexity: 45.73
# Epoch 36/60 - Train Loss: 2.2668, Val Loss: 3.8477, Val Perplexity: 46.89
# Epoch 37/60 - Train Loss: 2.2178, Val Loss: 3.8543, Val Perplexity: 47.20
# Epoch 38/60 - Train Loss: 2.1807, Val Loss: 3.8733, Val Perplexity: 48.10
# Epoch 39/60 - Train Loss: 2.1356, Val Loss: 3.8819, Val Perplexity: 48.52
# Epoch 40/60 - Train Loss: 2.0940, Val Loss: 3.9009, Val Perplexity: 49.45
# Epoch 41/60 - Train Loss: 2.0427, Val Loss: 3.9184, Val Perplexity: 50.32
# Epoch 42/60 - Train Loss: 2.0041, Val Loss: 3.9423, Val Perplexity: 51.54
# Epoch 43/60 - Train Loss: 1.9619, Val Loss: 3.9645, Val Perplexity: 52.70
# Epoch 44/60 - Train Loss: 1.9183, Val Loss: 3.9795, Val Perplexity: 53.49
# Epoch 45/60 - Train Loss: 1.8821, Val Loss: 3.9992, Val Perplexity: 54.55
# Epoch 46/60 - Train Loss: 1.8380, Val Loss: 4.0174, Val Perplexity: 55.56
# Epoch 47/60 - Train Loss: 1.7908, Val Loss: 4.0344, Val Perplexity: 56.51
# Epoch 48/60 - Train Loss: 1.7565, Val Loss: 4.0596, Val Perplexity: 57.95
# Epoch 49/60 - Train Loss: 1.7052, Val Loss: 4.0804, Val Perplexity: 59.17
# Epoch 50/60 - Train Loss: 1.6682, Val Loss: 4.0979, Val Perplexity: 60.22
# Epoch 51/60 - Train Loss: 1.6317, Val Loss: 4.1225, Val Perplexity: 61.72
# Epoch 52/60 - Train Loss: 1.5832, Val Loss: 4.1522, Val Perplexity: 63.58
# Epoch 53/60 - Train Loss: 1.5435, Val Loss: 4.1720, Val Perplexity: 64.85
# Epoch 54/60 - Train Loss: 1.5014, Val Loss: 4.1982, Val Perplexity: 66.57
# Epoch 55/60 - Train Loss: 1.4630, Val Loss: 4.2181, Val Perplexity: 67.90
# Epoch 56/60 - Train Loss: 1.4216, Val Loss: 4.2377, Val Perplexity: 69.25
# Epoch 57/60 - Train Loss: 1.3829, Val Loss: 4.2744, Val Perplexity: 71.84
# Epoch 58/60 - Train Loss: 1.3386, Val Loss: 4.3032, Val Perplexity: 73.93
# Epoch 59/60 - Train Loss: 1.3041, Val Loss: 4.3325, Val Perplexity: 76.13
# Epoch 60/60 - Train Loss: 1.2598, Val Loss: 4.3575, Val Perplexity: 78.06
# Plot saved to: exp_plots/loss_curves_optimizer_experiments.png
# Experiments Summary:
#
# Optimizer: AdamW
# LR: 0.0001, Shuffle: random, Batch Size: 1, Weight Decay: 0.0005
# Final Train Loss: 0.0579, Val Loss: 6.7704
#
# Optimizer: AdamW
# LR: 0.0001, Shuffle: random, Batch Size: 32, Weight Decay: 0.0005
# Final Train Loss: 1.2598, Val Loss: 4.3575

# %% [markdown]
# **Visualization**

# %%
# Crete loaders for plotting
train_loader, val_loader, _ = create_loaders(config) 

# Define paths for plotting
PATH = './exp_plots/'
paths = [PATH + f"segment_{models_names[0][:-3]}_{models_names[1][:-3]}.png",
        PATH + f"2D_plot_{models_names[0][:-3]}.png",
        PATH + f"2D_plot_{models_names[1][:-3]}.png"]

# Plot the experiment results
plot_experiment(models_list[0], models_list[1], train_loader, val_loader, config.device, paths=paths)
# Out:
# Plot saved to: ./exp_plots/segment_model_params_AdamW_0.0001_1_random_0.0005_model_params_AdamW_0.0001_32_random_0.0005.png
# Plot saved to: ./exp_plots/2D_plot_model_params_AdamW_0.0001_1_random_0.0005.png
# Plot saved to: ./exp_plots/2D_plot_model_params_AdamW_0.0001_32_random_0.0005.png

# %% [markdown]
# **Sharpness**

# %%
# Free some cuda memory by restarting with models on cpu
for model in models_list:
    model.to('cpu')

# %%
# Compute sharpness for each model
for i, model in enumerate(models_list):
    model.to(config.device)
    print(f"\nCalculating sharpness for model {i + 1} ({models_names[i]})...")
    sharpenss, hv_norm = calc_sharpness(model, train_loader, config.device)
    print(f"Model: {models_names[i]}, Sharpness: {sharpenss:.4f}%, HV Norm: {hv_norm:.4f} \n")
# Out:
# Calculating sharpness for model 1 (model_params_AdamW_0.0001_1_random_0.0005.pt)...
# Power Iteration:  20%|██        | 6/30 [00:08<00:34,  1.46s/it]
# Converged at iteration 7 with eigenvalue ≈ 17.2512
# Perturbation samples: 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
# Measured relative loss increase: -0.53%
# Predicted relative loss increase: -0.55%
# Linear term: -1.4506e-04
# Quadratic term (0.5 * eps^2 * lambda_max): 8.6256e-06
# Model: model_params_AdamW_0.0001_1_random_0.0005.pt, Sharpness: -15.7906%, HV Norm: 17.2512
#
#
# Calculating sharpness for model 2 (model_params_AdamW_0.0001_32_random_0.0005.pt)...
# Power Iteration:  40%|████      | 12/30 [00:15<00:23,  1.31s/it]
# Converged at iteration 13 with eigenvalue ≈ 2353.6985
# Perturbation samples: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# Measured relative loss increase: 0.20%
# Predicted relative loss increase: 0.24%
# Linear term: 2.3220e-04
# Quadratic term (0.5 * eps^2 * lambda_max): 1.1768e-03
# Model: model_params_AdamW_0.0001_32_random_0.0005.pt, Sharpness: -1.6172%, HV Norm: 2353.6985
