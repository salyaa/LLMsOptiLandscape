# %% [markdown]
# ## Batch Size & Weight Decay Experiments
#
# ### Configuration

# %%
import os
# Set the environment variable for CUDA devices
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# !export CUDA_VISIBLE_DEVICES=3
 
import warnings
import torch
from optimization.experiments import run_experiment, plot_experiment, calc_sharpness
from utils.config_loader import load_config
from utils.plots import plot_loss_curves
from utils.misc import set_seed, create_loaders

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*?.*")
warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch\.backends\.cuda\.sdp_kernel.*")

# Load config
config = load_config("config/base.yaml")

# Device setup
config.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set random seed for reproducibility
set_seed(42)

# Set a default number of epochs for experiments
EPOCHS = 60

# Create the results and plots directories if they do not exist
os.makedirs("exp_results", exist_ok=True)
os.makedirs("exp_plots", exist_ok=True)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\.'
# <>:16: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_151/1202273696.py:16: SyntaxWarning: invalid escape sequence '\.'
#   warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch\.backends\.cuda\.sdp_kernel.*")

# %% [markdown]
# ### Experiments

# %%
# Clear CUDA cache
torch.cuda.empty_cache()

# Define experiments
experiments = [
    {'optimizer_class': torch.optim.SGD, 'lr': 0.001, 'batch_size': 4, 'shuffle_mode': 'random', 'weight_decay': 0.0},
    {'optimizer_class': torch.optim.SGD, 'lr': 0.001, 'batch_size': 24, 'shuffle_mode': 'random', 'weight_decay': 0.0005},
]

# Initialize results and models list
results_list = []
models_list = []
models_names = []
    
# Run experiments
for exp in experiments:
    print(f"\nRunning experiment with {exp['optimizer_class'].__name__}, lr={exp['lr']}, bs={exp['batch_size']}, shuffle={exp['shuffle_mode']}, wd: {exp['weight_decay']}")
    
    results, model = run_experiment(
            config=config,
            optimizer_class=exp['optimizer_class'],
            lr=exp['lr'],
            weight_decay=exp['weight_decay'],
            batch_size=exp['batch_size'],
            epochs=EPOCHS,
            shuffle_mode=exp['shuffle_mode'],
        )
    
    results_list.append(results)
    models_list.append(model)

    # Generate a consistent filename
    fname = f"{exp['optimizer_class'].__name__}_{exp['lr']}_{exp['batch_size']}_{exp['shuffle_mode']}_{exp['weight_decay']}"

    # Save model state dict
    torch.save(model.state_dict(), f"exp_results/model_params_{fname}.pt")
    models_names.append(f"model_params_{fname}.pt")

    # Save results dict
    torch.save(results, f"exp_results/results_{fname}.pt")

# Plot loss curves with named output
if len(experiments) == 1:
    exp = experiments[0]
    fname = f"{exp['optimizer_class'].__name__}_{exp['lr']}_{exp['batch_size']}_{exp['shuffle_mode']}_{exp['weight_decay']}"
else:
    fname = "batch_size-weight_decay"

plot_loss_curves(results_list, save_path="exp_plots", fname=fname)

# Print exepriment summary
print("\nExperiments Summary:")
for res in results_list:
    print(f"\nOptimizer: {res['optimizer']}")
    print(f"LR: {res['lr']}, Shuffle: {res['shuffle_mode']}, Batch Size: {res['batch_size']}, Weight Decay: {res['weight_decay']}")
    print(f"Final Train Loss: {res['train_loss']:.4f}, Val Loss: {res['val_loss']:.4f}")
# Out:
# Running experiment with SGD, lr=0.001, bs=4, shuffle=random, wd: 0.0
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Epoch 1/60 - Train Loss: 5.1770, Val Loss: 5.1663, Val Perplexity: 175.27
# Epoch 2/60 - Train Loss: 5.2561, Val Loss: 3.8749, Val Perplexity: 48.18
# Epoch 3/60 - Train Loss: 4.7190, Val Loss: 4.1960, Val Perplexity: 66.42
# Epoch 4/60 - Train Loss: 4.7161, Val Loss: 4.3166, Val Perplexity: 74.93
# Epoch 5/60 - Train Loss: 4.5135, Val Loss: 3.9609, Val Perplexity: 52.50
# Epoch 6/60 - Train Loss: 4.5386, Val Loss: 4.6711, Val Perplexity: 106.81
# Epoch 7/60 - Train Loss: 4.5311, Val Loss: 3.8790, Val Perplexity: 48.38
# Epoch 8/60 - Train Loss: 4.3157, Val Loss: 4.7918, Val Perplexity: 120.52
# Epoch 9/60 - Train Loss: 4.2431, Val Loss: 3.5721, Val Perplexity: 35.59
# Epoch 10/60 - Train Loss: 4.1514, Val Loss: 3.5955, Val Perplexity: 36.43
# Epoch 11/60 - Train Loss: 4.0843, Val Loss: 3.5169, Val Perplexity: 33.68
# Epoch 12/60 - Train Loss: 4.1158, Val Loss: 3.6861, Val Perplexity: 39.89
# Epoch 13/60 - Train Loss: 4.0262, Val Loss: 3.6148, Val Perplexity: 37.14
# Epoch 14/60 - Train Loss: 4.0145, Val Loss: 4.2431, Val Perplexity: 69.62
# Epoch 15/60 - Train Loss: 3.9713, Val Loss: 3.3994, Val Perplexity: 29.94
# Epoch 16/60 - Train Loss: 4.1068, Val Loss: 4.4939, Val Perplexity: 89.47
# Epoch 17/60 - Train Loss: 3.9365, Val Loss: 4.0966, Val Perplexity: 60.14
# Epoch 18/60 - Train Loss: 3.8786, Val Loss: 3.2975, Val Perplexity: 27.05
# Epoch 19/60 - Train Loss: 3.9148, Val Loss: 3.5079, Val Perplexity: 33.38
# Epoch 20/60 - Train Loss: 3.8518, Val Loss: 3.8847, Val Perplexity: 48.65
# Epoch 21/60 - Train Loss: 3.9015, Val Loss: 4.9175, Val Perplexity: 136.66
# Epoch 22/60 - Train Loss: 3.7950, Val Loss: 3.5012, Val Perplexity: 33.16
# Epoch 23/60 - Train Loss: 3.8745, Val Loss: 3.7320, Val Perplexity: 41.76
# Epoch 24/60 - Train Loss: 3.8156, Val Loss: 3.2985, Val Perplexity: 27.07
# Epoch 25/60 - Train Loss: 3.8004, Val Loss: 3.6120, Val Perplexity: 37.04
# Epoch 26/60 - Train Loss: 3.9298, Val Loss: 3.8134, Val Perplexity: 45.30
# Epoch 27/60 - Train Loss: 3.7783, Val Loss: 3.7644, Val Perplexity: 43.14
# Epoch 28/60 - Train Loss: 3.7329, Val Loss: 4.0018, Val Perplexity: 54.70
# Epoch 29/60 - Train Loss: 3.7151, Val Loss: 3.4520, Val Perplexity: 31.56
# Epoch 30/60 - Train Loss: 3.7547, Val Loss: 3.6303, Val Perplexity: 37.72
# Epoch 31/60 - Train Loss: 3.7214, Val Loss: 3.8680, Val Perplexity: 47.85
# Epoch 32/60 - Train Loss: 3.7527, Val Loss: 3.7782, Val Perplexity: 43.74
# Epoch 33/60 - Train Loss: 3.6904, Val Loss: 3.4867, Val Perplexity: 32.68
# Epoch 34/60 - Train Loss: 3.7045, Val Loss: 4.1178, Val Perplexity: 61.42
# Epoch 35/60 - Train Loss: 3.7131, Val Loss: 3.9204, Val Perplexity: 50.42
# Epoch 36/60 - Train Loss: 3.7094, Val Loss: 3.4133, Val Perplexity: 30.36
# Epoch 37/60 - Train Loss: 3.6387, Val Loss: 4.0209, Val Perplexity: 55.75
# Epoch 38/60 - Train Loss: 3.7953, Val Loss: 3.5141, Val Perplexity: 33.58
# Epoch 39/60 - Train Loss: 3.6751, Val Loss: 3.3439, Val Perplexity: 28.33
# Epoch 40/60 - Train Loss: 3.6945, Val Loss: 3.4306, Val Perplexity: 30.90
# Epoch 41/60 - Train Loss: 3.5961, Val Loss: 3.3793, Val Perplexity: 29.35
# Epoch 42/60 - Train Loss: 3.6212, Val Loss: 3.5423, Val Perplexity: 34.55
# Epoch 43/60 - Train Loss: 3.6030, Val Loss: 3.5254, Val Perplexity: 33.97
# Epoch 44/60 - Train Loss: 3.6244, Val Loss: 3.7028, Val Perplexity: 40.56
# Epoch 45/60 - Train Loss: 3.5726, Val Loss: 3.4315, Val Perplexity: 30.92
# Epoch 46/60 - Train Loss: 3.6225, Val Loss: 3.4898, Val Perplexity: 32.78
# Epoch 47/60 - Train Loss: 3.5969, Val Loss: 3.5632, Val Perplexity: 35.28
# Epoch 48/60 - Train Loss: 3.6575, Val Loss: 3.8582, Val Perplexity: 47.38
# Epoch 49/60 - Train Loss: 3.5861, Val Loss: 3.5343, Val Perplexity: 34.27
# Epoch 50/60 - Train Loss: 3.5413, Val Loss: 3.3576, Val Perplexity: 28.72
# Epoch 51/60 - Train Loss: 3.5872, Val Loss: 3.9955, Val Perplexity: 54.35
# Epoch 52/60 - Train Loss: 3.5675, Val Loss: 3.4509, Val Perplexity: 31.53
# Epoch 53/60 - Train Loss: 3.5704, Val Loss: 3.9018, Val Perplexity: 49.49
# Epoch 54/60 - Train Loss: 3.5526, Val Loss: 3.6387, Val Perplexity: 38.04
# Epoch 55/60 - Train Loss: 3.5830, Val Loss: 3.3281, Val Perplexity: 27.89
# Epoch 56/60 - Train Loss: 3.5568, Val Loss: 3.3709, Val Perplexity: 29.11
# Epoch 57/60 - Train Loss: 3.5508, Val Loss: 3.5268, Val Perplexity: 34.01
# Epoch 58/60 - Train Loss: 3.5080, Val Loss: 3.7044, Val Perplexity: 40.62
# Epoch 59/60 - Train Loss: 3.5156, Val Loss: 3.4278, Val Perplexity: 30.81
# Epoch 60/60 - Train Loss: 3.5596, Val Loss: 3.5092, Val Perplexity: 33.42
#
# Running experiment with SGD, lr=0.001, bs=24, shuffle=random, wd: 0.0005
# Epoch 1/60 - Train Loss: 10.5006, Val Loss: 10.3228, Val Perplexity: 30418.39
# Epoch 2/60 - Train Loss: 20.4489, Val Loss: 16.3830, Val Perplexity: 13033304.00
# Epoch 3/60 - Train Loss: 10.5194, Val Loss: 7.4689, Val Perplexity: 1752.73
# Epoch 4/60 - Train Loss: 8.2352, Val Loss: 5.4203, Val Perplexity: 225.95
# Epoch 5/60 - Train Loss: 7.1146, Val Loss: 7.4349, Val Perplexity: 1694.14
# Epoch 6/60 - Train Loss: 7.8265, Val Loss: 5.2413, Val Perplexity: 188.92
# Epoch 7/60 - Train Loss: 6.7805, Val Loss: 5.4415, Val Perplexity: 230.79
# Epoch 8/60 - Train Loss: 6.4521, Val Loss: 5.1685, Val Perplexity: 175.65
# Epoch 9/60 - Train Loss: 6.6513, Val Loss: 4.8536, Val Perplexity: 128.20
# Epoch 10/60 - Train Loss: 6.2514, Val Loss: 4.6620, Val Perplexity: 105.85
# Epoch 11/60 - Train Loss: 5.8574, Val Loss: 5.2602, Val Perplexity: 192.52
# Epoch 12/60 - Train Loss: 5.8431, Val Loss: 4.9260, Val Perplexity: 137.83
# Epoch 13/60 - Train Loss: 5.8455, Val Loss: 4.9339, Val Perplexity: 138.92
# Epoch 14/60 - Train Loss: 5.7831, Val Loss: 4.8811, Val Perplexity: 131.77
# Epoch 15/60 - Train Loss: 5.6319, Val Loss: 4.3859, Val Perplexity: 80.31
# Epoch 16/60 - Train Loss: 5.5315, Val Loss: 4.6776, Val Perplexity: 107.52
# Epoch 17/60 - Train Loss: 5.4785, Val Loss: 4.6370, Val Perplexity: 103.23
# Epoch 18/60 - Train Loss: 5.5609, Val Loss: 4.6101, Val Perplexity: 100.50
# Epoch 19/60 - Train Loss: 5.3996, Val Loss: 4.3432, Val Perplexity: 76.95
# Epoch 20/60 - Train Loss: 5.3286, Val Loss: 4.8062, Val Perplexity: 122.27
# Epoch 21/60 - Train Loss: 5.6202, Val Loss: 4.8319, Val Perplexity: 125.45
# Epoch 22/60 - Train Loss: 5.2826, Val Loss: 4.4432, Val Perplexity: 85.05
# Epoch 23/60 - Train Loss: 5.1732, Val Loss: 5.4644, Val Perplexity: 236.13
# Epoch 24/60 - Train Loss: 5.3823, Val Loss: 4.6328, Val Perplexity: 102.80
# Epoch 25/60 - Train Loss: 5.2152, Val Loss: 4.6769, Val Perplexity: 107.43
# Epoch 26/60 - Train Loss: 5.0914, Val Loss: 4.3059, Val Perplexity: 74.13
# Epoch 27/60 - Train Loss: 5.0800, Val Loss: 4.1298, Val Perplexity: 62.17
# Epoch 28/60 - Train Loss: 5.1514, Val Loss: 5.0410, Val Perplexity: 154.63
# Epoch 29/60 - Train Loss: 5.1035, Val Loss: 4.4627, Val Perplexity: 86.72
# Epoch 30/60 - Train Loss: 5.1062, Val Loss: 4.6823, Val Perplexity: 108.02
# Epoch 31/60 - Train Loss: 5.1150, Val Loss: 4.1006, Val Perplexity: 60.38
# Epoch 32/60 - Train Loss: 5.0987, Val Loss: 4.1604, Val Perplexity: 64.10
# Epoch 33/60 - Train Loss: 4.9142, Val Loss: 4.3153, Val Perplexity: 74.84
# Epoch 34/60 - Train Loss: 4.8927, Val Loss: 4.2713, Val Perplexity: 71.61
# Epoch 35/60 - Train Loss: 4.9147, Val Loss: 4.5219, Val Perplexity: 92.01
# Epoch 36/60 - Train Loss: 5.3996, Val Loss: 4.1343, Val Perplexity: 62.45
# Epoch 37/60 - Train Loss: 4.8174, Val Loss: 4.1737, Val Perplexity: 64.96
# Epoch 38/60 - Train Loss: 4.9627, Val Loss: 4.0261, Val Perplexity: 56.04
# Epoch 39/60 - Train Loss: 4.8167, Val Loss: 4.3209, Val Perplexity: 75.25
# Epoch 40/60 - Train Loss: 4.8305, Val Loss: 4.2981, Val Perplexity: 73.56
# Epoch 41/60 - Train Loss: 4.7548, Val Loss: 4.7421, Val Perplexity: 114.68
# Epoch 42/60 - Train Loss: 4.8214, Val Loss: 5.0026, Val Perplexity: 148.80
# Epoch 43/60 - Train Loss: 4.7397, Val Loss: 4.7893, Val Perplexity: 120.21
# Epoch 44/60 - Train Loss: 4.8205, Val Loss: 4.3044, Val Perplexity: 74.03
# Epoch 45/60 - Train Loss: 4.8604, Val Loss: 4.4823, Val Perplexity: 88.44
# Epoch 46/60 - Train Loss: 4.7418, Val Loss: 5.6282, Val Perplexity: 278.15
# Epoch 47/60 - Train Loss: 4.7986, Val Loss: 4.1747, Val Perplexity: 65.02
# Epoch 48/60 - Train Loss: 4.8008, Val Loss: 4.7773, Val Perplexity: 118.79
# Epoch 49/60 - Train Loss: 5.0050, Val Loss: 4.3042, Val Perplexity: 74.01
# Epoch 50/60 - Train Loss: 4.5914, Val Loss: 5.1453, Val Perplexity: 171.62
# Epoch 51/60 - Train Loss: 4.7132, Val Loss: 3.9538, Val Perplexity: 52.13
# Epoch 52/60 - Train Loss: 4.6841, Val Loss: 4.2254, Val Perplexity: 68.40
# Epoch 53/60 - Train Loss: 4.7439, Val Loss: 4.3027, Val Perplexity: 73.90
# Epoch 54/60 - Train Loss: 4.5910, Val Loss: 4.1099, Val Perplexity: 60.94
# Epoch 55/60 - Train Loss: 4.6115, Val Loss: 4.3964, Val Perplexity: 81.16
# Epoch 56/60 - Train Loss: 4.6239, Val Loss: 4.2772, Val Perplexity: 72.04
# Epoch 57/60 - Train Loss: 4.5826, Val Loss: 4.1951, Val Perplexity: 66.36
# Epoch 58/60 - Train Loss: 4.6311, Val Loss: 3.9602, Val Perplexity: 52.47
# Epoch 59/60 - Train Loss: 4.6516, Val Loss: 4.6208, Val Perplexity: 101.57
# Epoch 60/60 - Train Loss: 4.5622, Val Loss: 4.1897, Val Perplexity: 66.00
# Plot saved to: exp_plots/loss_curves_batch_size.png
# Experiments Summary:
#
# Optimizer: SGD
# LR: 0.001, Shuffle: random, Batch Size: 4, Weight Decay: 0.0
# Final Train Loss: 3.5596, Val Loss: 3.5092
#
# Optimizer: SGD
# LR: 0.001, Shuffle: random, Batch Size: 24, Weight Decay: 0.0005
# Final Train Loss: 4.5622, Val Loss: 4.1897

# %% [markdown]
# **Visualization**

# %%
# Crete loaders for plotting
train_loader, val_loader, _ = create_loaders(config) 

# Define paths for plotting
PATH = './exp_plots/'
paths = [PATH + f"segment_{models_names[0][:-3]}_{models_names[1][:-3]}.png",
        PATH + f"2D_plot_{models_names[0][:-3]}.png",
        PATH + f"2D_plot_{models_names[1][:-3]}.png"]

# Plot the experiment results
plot_experiment(models_list[0], models_list[1], train_loader, val_loader, config.device, paths=paths)
# Out:
# Plot saved to: ./exp_plots/TESTsegment_model_params_SGD_0.001_4_random_0.0_model_params_SGD_0.001_24_random_0.0005.png
# Plot saved to: ./exp_plots/TEST2D_plot_model_params_SGD_0.001_4_random_0.0.png
# Plot saved to: ./exp_plots/TEST2D_plot_model_params_SGD_0.001_24_random_0.0005.png

# %% [markdown]
# **Sharpness**

# %%
# Compute sharpness for each model
for i, model in enumerate(models_list):
    print(f"\nCalculating sharpness for model {i + 1} ({models_names[i]})...")
    sharpenss, hv_norm = calc_sharpness(model, train_loader, config.device)
    print(f"Model: {models_names[i]}, Sharpness: {sharpenss:.4f}%, HV Norm: {hv_norm:.4f} \n")
# Out:
# Calculating sharpness for model 1 (model_params_SGD_0.001_4_random_0.0.pt)...
# Power Iteration:  23%|██▎       | 7/30 [00:07<00:24,  1.07s/it]
# Converged at iteration 8 with eigenvalue ≈ 5042.6211
# Perturbation samples: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
# Measured relative loss increase: 1.33%
# Predicted relative loss increase: 1.34%
# Linear term: 4.2822e-02
# Quadratic term (0.5 * eps^2 * lambda_max): 2.5213e-03
# Model: model_params_SGD_0.001_4_random_0.0.pt, Sharpness: 21.8840%, HV Norm: 5042.6211
#
#
# Calculating sharpness for model 2 (model_params_SGD_0.001_24_random_0.0005.pt)...
# Power Iteration:  53%|█████▎    | 16/30 [00:15<00:13,  1.01it/s]
# Converged at iteration 17 with eigenvalue ≈ 8943.1494
# Perturbation samples: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
# Measured relative loss increase: -1.25%
# Predicted relative loss increase: -1.24%
# Linear term: -5.5977e-02
# Quadratic term (0.5 * eps^2 * lambda_max): 4.4716e-03
# Model: model_params_SGD_0.001_24_random_0.0005.pt, Sharpness: 15.7402%, HV Norm: 8943.1494
